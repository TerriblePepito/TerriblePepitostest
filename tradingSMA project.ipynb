# %% [markdown]
# <a href="https://colab.research.google.com/github/TerriblePepito/TerriblePepitostest/blob/main/tradingSMA%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bt
import bt

# %%
# !pip install git+https://github.com/mrjbq7/ta-lib.git
# Out:
# ...
#   Cloning https://github.com/mrjbq7/ta-lib.git to /tmp/pip-req-build-sijxpk3t
#   Running command git clone --filter=blob:none --quiet https://github.com/mrjbq7/ta-lib.git /tmp/pip-req-build-sijxpk3t
#   Resolved https://github.com/mrjbq7/ta-lib.git to commit 0c957ed45e6371925cf0e4f44cc06833306c659c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for ta-lib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for ta-lib
# Failed to build ta-lib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (ta-lib)

# %%
# !pip install ta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=16a79556ec3b9fd2c7a5acd498433dd0bbeb97dfb4b5c64e309097376784b9b2
#   Stored in directory: /root/.cache/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# ...

# %%
import ta

# %%
get_data=bt.get('BTC-USD')
import pandas as pd
df=pd.DataFrame(get_data)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 btcusd
# Date
# 2014-09-17  457.334015
# 2014-09-18  424.440002
# 2014-09-19  394.795990
# 2014-09-20  408.903992
# 2014-09-21  398.821014

# %%
import matplotlib.pyplot as plt
plt.plot(df['btcusd'])
plt.show()

# %%
get_data1=bt.get('NRGV')
import pandas as pd
df1=pd.DataFrame(get_data1)
df1.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#              nrgv
# Date
# 2021-03-29  9.650
# 2021-03-30  9.660
# 2021-03-31  9.700
# 2021-04-01  9.750
# 2021-04-05  9.758

# %%
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-12-8d4e5e4ea11c> in <cell line: 0>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=df1)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display, backend)
#     147       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     148     self._credentials = credentials
# --> 149     self._ensure_gspread_client()
#     150
#     151     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     217     global _gspread_client
#     218     if _gspread_client is None:
# --> 219       creds = InteractiveSheet.generate_creds(self._credentials)
# ...

# %%
SMA1=ta.trend.SMAIndicator(df1['nrgv'],window=50)
SMA2=ta.trend.SMAIndicator(df1['nrgv'],window=200)
df1['SMA1']=SMA1.sma_indicator()
df1['SMA2']=SMA2.sma_indicator()
df1.head()
# Out:
#              nrgv  SMA1  SMA2
# Date
# 2021-03-29  9.650   NaN   NaN
# 2021-03-30  9.660   NaN   NaN
# 2021-03-31  9.700   NaN   NaN
# 2021-04-01  9.750   NaN   NaN
# 2021-04-05  9.758   NaN   NaN

# %%
plt.plot(df1['nrgv'])
plt.plot(df1['SMA1'])
plt.plot(df1['SMA2'])
plt.show()
